# %% [markdown]
# # <center>PGP Data Science Engineering</center>
# ## <center>Introduction to Programming – Mini Project:</center>

# %% [markdown]
# ### Problem 1:
#
# 1. Write a program to calculate area of shapes. Your program should be capable of calculating the area of a square, rectangle, triangle and a circle. The user should be presented with options to select the shape. Based on which shape is chosed by the user, the program should ask for the appropriate input and print the resulting area on the screen.
#
# When the program is run, the screen should display something like this:
#
# **Which shape would you like to calculate the area for? Please enter the option number-**<br>
# **1. Square**<br>
# **2. Rectangle**<br>
# **3. Triangle**<br>
# **4. Circle**<br>
# **Enter Option: _**
#
# Say the user enters the option 1.
#
# **Please enter the length of a side: _**
#
# If the user enters a value of 5. The output should be:
#
# **The area of the square is 25**
#
# This program should indicate that the input is invalid if the user enters a character instead of a number as input. For instance if the user enters a value of ‘a’ instead of 5 in the previous example the program should prompt:
#
# **Invalid input, please enter a number: _**

# %%
while(True):
    print('''Which shape would you like to calculate the area for? Please enter the option number-
1. Square
2. Rectangle
3. Triangle
4. Circle
0. Exit''')
    
    print()
    n = input("Enter Option: ")
    print()
    
    if(n == '1'):
        try:
            a = float(input("Please enter the length of a side: "))
        except:
            a = float(input("Invalid input, please enter a number: "))
        print()
        print("The area of the square is:",a*a)
        
    elif(n == '2'):
        try:
            a = float(input("Please enter the length of the rectangle: "))
        except:
            a = float(input("Invalid input, Please a number: "))
        try:
            b = float(input("Please enter the breadth of the rectangle: "))
        except:
            b = float(input("Invalid input, Please a number: "))
        print()
        print("The area of the rectangle is:",a*b)
        
    elif(n == '3'):
        try:
            b = float(input("Please enter the base of the triangle: "))
        except:
            b = float(input("Invalid input, Please a number: "))
        try:
            h = float(input("Please enter the height of the triangle: "))
        except:
            h = float(input("Invalid input, Please a number: "))
        print()
        print("The area of the triangle is:",(1/2)*b*h)
        
    elif(n == '4'):
        try:
            r = float(input("Please enter the radius of the circle: "))
        except:
            r = float(input("Invalid input, Please a number: "))
        print()
        print("The are of the circle is:",3.14*r*r)
    
    elif(n == '0'):
        print("Thank you for using area calculator")
        break
        
    else:
        print()
        print("Please select the correct option")
        continue
        
    print()   
    print("-"*100)
    print()
# Out:
# Which shape would you like to calculate the area for? Please enter the option number-
# 1. Square
# 2. Rectangle
# 3. Triangle
# 4. Circle
# 0. Exit
#
# Enter Option: 1
#
# Please enter the length of a side: a
# Invalid input, please enter a number: 5
#
# The area of the square is: 25.0
#
# ----------------------------------------------------------------------------------------------------
#
# Which shape would you like to calculate the area for? Please enter the option number-
# 1. Square
# 2. Rectangle
# 3. Triangle
# 4. Circle
# 0. Exit
#
# Enter Option: 2
#
# Please enter the length of the rectangle: a
# Invalid input, Please a number: 2
# Please enter the breadth of the rectangle: d
# Invalid input, Please a number: 4
#
# The area of the rectangle is: 8.0
#
# ----------------------------------------------------------------------------------------------------
#
# Which shape would you like to calculate the area for? Please enter the option number-
# 1. Square
# 2. Rectangle
# ...

# %% [markdown]
# ### Problem 2:
#
# Create and encrypter in python based on the ceaser cipher. It is a substitution cipher where each character of the original text is shifted a certain number characters in the alphabet. Write a function that would require 2 arguments – the input text to be encrypted and a key. For eg: Given the input text ‘hello’ and the key 3, the resulting encryted text would be ‘khoor’. Here you can see that every character in the string hello is shifted by 3 characters. ‘h’ has shifted to ‘k’, ‘e’ has shifted to ‘h’ and so on. If a key of 5 were used, the resulting string would be ‘mjqqt’. This function should be capable of ignoring any characters which are not alphabets. Th2 character ‘z’ entered b
# y the user for a key of 3 would result in ‘c’.
#
# Usage:<br>
# **encrypt(‘hello world!’, 3)**<br>
# **‘khoor zruog!’**
#
# Similarly create decrypter which can decode the encryted text when provided the input text and key
#
# Usage:<br>
# **decrypt(‘khoor zruog!’, 3)**<br>
# **‘hello world!’**
#
# For the sake of simplicity you can assume that input solely consists of lowercase alphabets, spaces and punctuation symbols. Numbers in the input text would also be ignored similar to symbols.

# %%
alphabets = []
for i in range(97,123):
    alphabets.append(chr(i))
alphabets.extend(alphabets)
result = []

def encrypt(text, key):
    for j in text:
        if(j in alphabets):
            result.append(alphabets[alphabets.index(j) + key])
        else:
            result.append(j)
    for k in result:
        print(k,end='')
    result.clear()
    
def decrypt(text, key):
    for j in text:
        if(j in alphabets):
            result.append(alphabets[alphabets.index(j) - key])
        else:
            result.append(j)
    for k in result:
        print(k,end='')
    result.clear()
    
while(True):
    print('''What do you want to use ?
    1. Encrypter
    2. Decrypter
    0. Exit''')
    print()
    n = int(input("Enter your choice: "))
    print()
    
    if(n == 1):
        inp = input("Enter your text: ")
        key = int(input("Enter your key: "))
        print()
        if(key in range(1,26)):
            encrypt(inp, key)
        else:
            key = int(input("Enter a key from 1 to 25: "))
            encrypt(inp,key)
            
    elif(n == 2):
        inp = input("Enter your text: ")
        key = int(input("Enter your key: "))
        print()
        if(key in range(1,26)):
            decrypt(inp, key)
        else:
            key = int(input("Enter a key from 1 to 25: "))
            decrypt(inp,key)
    
    elif(n == 0):
        print("Thank you for using Encrypter / Decrypter")
        break
        
    else:
        print("Enter the right choice")
        continue
        
    print()
    print('-'*100)
    print()
# Out:
# What do you want to use ?
#     1. Encrypter
#     2. Decrypter
#     0. Exit
#
# Enter your choice: 1
#
# Enter your text: hello world!
# Enter your key: 3
#
# khoor zruog!
# ----------------------------------------------------------------------------------------------------
#
# What do you want to use ?
#     1. Encrypter
#     2. Decrypter
#     0. Exit
#
# Enter your choice: 2
#
# Enter your text: khoor zruog!
# Enter your key: 3
#
# hello world!
# ----------------------------------------------------------------------------------------------------
#
# What do you want to use ?
#     1. Encrypter
#     2. Decrypter
#     0. Exit
#
# Enter your choice: 1
#
# Enter your text: hello world! 2
# Enter your key: 3
#
# khoor zruog! 2
# ----------------------------------------------------------------------------------------------------
#
# What do you want to use ?
#     1. Encrypter
#     2. Decrypter
#     0. Exit
#
# Enter your choice: 2
#
# Enter your text: khoor zruog! 2
# ...
